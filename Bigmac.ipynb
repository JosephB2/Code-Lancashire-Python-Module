# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Datasets/BigmacPrice.csv')

# %%
df.head()
# Out:
#         date currency_code       name  local_price  dollar_ex  dollar_price
# 0 2000-04-01           ARS  Argentina         2.50          1          2.50
# 1 2000-04-01           AUD  Australia         2.59          1          2.59
# 2 2000-04-01           BRL     Brazil         2.95          1          2.95
# 3 2000-04-01           GBP    Britain         1.90          1          1.90
# 4 2000-04-01           CAD     Canada         2.85          1          2.85

# %%
df.date = pd.to_datetime(df.date)

# %%
br = df[df.name=='Brazil']
br.set_index('date', inplace=True)

jp = df[df.name=='Japan']
jp.set_index('date', inplace=True)

# %%
br.plot()
# Out:
# <Axes: xlabel='date'>

# %%
jp.plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.sort_values(by='dollar_price', ascending=False).head(20)
# Out:
#           date currency_code       name  local_price  dollar_ex  dollar_price
# 687 2013-01-01           BRL     Brazil        11.25          1         11.25
# 579 2012-01-01           BRL     Brazil        10.25          1         10.25
# 737 2013-01-01           VEF  Venezuela        39.00          4          9.75
# 524 2011-07-01           BRL     Brazil         9.50          1          9.50
# 552 2011-07-01           NOK     Norway        45.00          5          9.00
# 481 2010-07-01           BRL     Brazil         8.71          1          8.71
# 715 2013-01-01           NOK     Norway        43.00          5          8.60
# 787 2013-07-01           TRY     Turkey         8.50          1          8.50
# 682 2012-07-01           VEF  Venezuela        34.00          4          8.50
# 732 2013-01-01           TRY     Turkey         8.45          1          8.45
# 677 2012-07-01           TRY     Turkey         8.25          1          8.25
# ...
